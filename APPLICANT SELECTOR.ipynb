# %% [markdown]
# # CLOUD COUNSELAGE LIVE PROJECT
# ## WEEK - 1

# %% [markdown]
# ### Problem Statement
#  Students from different cities from the state of Maharashtra had applied for the Cloud Counselage Internship Program. We have the data set of consisting information of all the students. Using this data we want to get more insights and draw out more meaningful conclusions. Interns are expected to build a data visualization model and find the best data segmentation model using the student’s dataset.
#
# Following are the tasks interns need to perform:
#
#     1.Interns need to preprocess the data for missing values, unknown values, encoding categorical values.
#     2.Create a data visualization model to build graphs from the data set answering the following questions:
#         a.The number of students applied to different technologies.
#         b.The number of students applied for Data Science who knew "Python” and who didn’t.
#         c.The different ways students learned about this program.
#         d.Students who are in the fourth year and have a CGPA greater than 8.0.
#         e.Students who applied for Digital Marketing with verbal and written communication score greater than 8.
#         f.Year-wise and area of study wise classification of students.
#         g.City and college wise classification of students.
#         h.Plot the relationship between the CGPA and the target variable.
#         i.Plot the relationship between the Area of Interest and the target variable.
#         j.Plot the relationship between the year of study, major, and the target variable.
#     3.Identify the best binary classifier to classify data into “eligible/1” and “not eligible/0”.

# %% [markdown]
# #### Import the required modules

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display
pd.options.display.max_columns = None

# %% [markdown]
# #### Create Dataframe

# %%
df = pd.read_csv("DS_DATESET.csv")

# %%
# Columns in the dataframe
df.columns
# Out:
# Index(['First Name', 'Last Name', 'City', 'State', 'Zip Code',
#        'DOB [DD/MM/YYYY]', 'Age', 'Gender', 'Email Address', 'Contact Number',
#        'Emergency Contact Number', 'College name', 'University Name', 'Degree',
#        'Major/Area of Study', 'Course Type', 'Which-year are you studying in?',
#        'CGPA/ percentage', 'Expected Graduation-year', 'Areas of interest',
#        'Current Employment Status', 'Have you worked core Java',
#        'Programming Language Known other than Java (one major)',
#        'Have you worked on MySQL or Oracle database',
#        'Have you studied OOP Concepts',
#        'Certifications/Achievement/ Research papers',
#        'Rate your written communication skills [1-10]',
#        'Rate your verbal communication skills [1-10]',
#        'Link to updated Resume (Google/ One Drive link preferred)',
#        'link to Linkedin profile', 'How Did You Hear About This Internship?',
#        'Label'],
#       dtype='object')

# %%
# First five rows of dataframe
df.head()
# Out:
#   First Name Last Name      City        State  Zip Code DOB [DD/MM/YYYY]  Age  \
# 0     Barron    Harnes  Kolhapur  Maharashtra    416004       24/09/2000   19
# 1      Velma    Allone      Pune  Maharashtra    411011       23/10/1997   22
# 2    Thibaut  Scotland    Mumbai  Maharashtra    400059         6/2/1996   24
# 3      Retha     Proud   Solapur  Maharashtra    413224       26/12/1999   20
# 4        Del    Pearse    Sangli  Maharashtra    416436       21/09/1996   23
#
#    Gender              Email Address  Contact Number  \
# 0    Male       bharnes0@harvard.edu      6345186600
# 1  Female            vallone1@i2i.jp      2808753102
# 2    Male  tscotland2@opensource.org      2945231918
# 3  Female         rproud3@flavors.me      7507196200
# 4  Female      dpearse4@sakura.ne.jp      6643884281
#
#    Emergency Contact Number                                     College name  \
# 0                7828240738   DY Patil College of Engineering And Technology
# 1                2891397791  Vishwakarma Institute of Information Technology
# 2                9388905869              Vidyalankar Institute of Technology
# 3                8037797161        Brahmdevdada Mane Institute of Technology
# 4                1328949359              Rajarambapu Institute of Technology
#
#                                    University Name  Degree  \
# 0                               Shivaji University  B.Tech
# 1                 Savitribai Phule Pune University  B.Tech
# 2                                Mumbai University    B.E.
# 3  Punyashlok Ahilyadevi Holkar Solapur University  B.Tech
# 4                               Shivaji University  B.Tech
#
#                  Major/Area of Study Course Type  \
# 0             Electrical Engineering  Full-time
# 1  Electronics and Telecommunication  Full-time
# 2             Electrical Engineering  Full-time
# 3               Computer Engineering  Full-time
# 4             Electrical Engineering  Full-time
#
#   Which-year are you studying in?  CGPA/ percentage  Expected Graduation-year  \
# 0                     Second-year              7.26                      2022
# 1                     Fourth-year              8.73                      2020
# 2                     Fourth-year              8.61                      2020
# 3                     Second-year              7.96                      2022
# 4                      First-year              7.07                      2023
#
#           Areas of interest Current Employment Status  \
# 0  Artificial Intelligence                    Student
# 1          Cloud Computing                    Student
# 2                      IoT                    Student
# 3        Digital Marketing                    Student
# 4          Cloud Computing                    Student
#
#   Have you worked core Java  \
# 0                       Yes
# 1                       Yes
# 2                       Yes
# 3                        No
# 4                        No
#
#   Programming Language Known other than Java (one major)  \
# 0                                           HTML/CSS
# 1                                                PHP
# 2                                                  C
# 3                                                PHP
# 4                                             Python
#
#   Have you worked on MySQL or Oracle database Have you studied OOP Concepts  \
# 0                                         Yes                            No
# 1                                          No                           Yes
# 2                                          No                            No
# 3                                          No                           Yes
# 4                                          No                           Yes
#
#    Certifications/Achievement/ Research papers  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#    Rate your written communication skills [1-10]  \
# 0                                              6
# 1                                             10
# 2                                              8
# 3                                              9
# 4                                              8
#
#    Rate your verbal communication skills [1-10]  \
# 0                                            10
# 1                                             7
# 2                                             6
# 3                                             6
# 4                                             6
#
#    Link to updated Resume (Google/ One Drive link preferred)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    link to Linkedin profile How Did You Hear About This Internship?  \
# 0                       NaN                                 Twitter
# 1                       NaN                     Ex/Current Employee
# 2                       NaN                                 Twitter
# 3                       NaN                                 Twitter
# 4                       NaN                                Facebook
#
#         Label
# 0  ineligible
# 1    eligible
# 2  ineligible
# 3  ineligible
# 4  ineligible

# %%
# Shape of dataframe
df.shape
# Out:
# (10000, 32)

# %% [markdown]
# ##### Exploratory data analysis

# %%
# Graph of distribution 
df.Label.value_counts().plot.pie(figsize=(6,6), autopct='%1.1f%%')
plt.show()

# %%
df.Age.hist()
plt.title("Distribution of Age")
plt.xlabel("Age")
plt.ylabel("Number of Students")
plt.show()

# %%
df.Gender.value_counts().plot.pie(figsize=(6,6), autopct='%1.1f%%')
plt.show()

# %%
df.City.value_counts().plot.pie(figsize=(6,6), autopct='%1.1f%%')
plt.show()

# %%
df["Which-year are you studying in?"].value_counts().plot.pie(figsize=(6,6), autopct='%1.1f%%')
plt.show()

# %%
df["How Did You Hear About This Internship?"].value_counts().plot.pie(figsize=(6,6), autopct='%1.1f%%')
plt.show()

# %% [markdown]
# #### Preprocess the data for missing values, unknown values, encoding categorical values.

# %%
# Null values sorted in descending order
((df.isnull().sum()/len(df))*100).sort_values(ascending=False)
# Out:
# link to Linkedin profile                                     100.0
# Link to updated Resume (Google/ One Drive link preferred)    100.0
# Certifications/Achievement/ Research papers                  100.0
# Label                                                          0.0
# Age                                                            0.0
# College name                                                   0.0
# Emergency Contact Number                                       0.0
# Contact Number                                                 0.0
# Email Address                                                  0.0
# Gender                                                         0.0
# Zip Code                                                       0.0
# DOB [DD/MM/YYYY]                                               0.0
# Degree                                                         0.0
# State                                                          0.0
# City                                                           0.0
# Last Name                                                      0.0
# University Name                                                0.0
# Course Type                                                    0.0
# Major/Area of Study                                            0.0
# How Did You Hear About This Internship?                        0.0
# Which-year are you studying in?                                0.0
# CGPA/ percentage                                               0.0
# Expected Graduation-year                                       0.0
# Areas of interest                                              0.0
# Current Employment Status                                      0.0
# Have you worked core Java                                      0.0
# Programming Language Known other than Java (one major)         0.0
# Have you worked on MySQL or Oracle database                    0.0
# Have you studied OOP Concepts                                  0.0
# Rate your written communication skills [1-10]                  0.0
# Rate your verbal communication skills [1-10]                   0.0
# First Name                                                     0.0
# dtype: float64

# %%
# Check the data types of dataframe
df.dtypes
# Out:
# First Name                                                    object
# Last Name                                                     object
# City                                                          object
# State                                                         object
# Zip Code                                                       int64
# DOB [DD/MM/YYYY]                                              object
# Age                                                            int64
# Gender                                                        object
# Email Address                                                 object
# Contact Number                                                 int64
# Emergency Contact Number                                       int64
# College name                                                  object
# University Name                                               object
# Degree                                                        object
# Major/Area of Study                                           object
# Course Type                                                   object
# Which-year are you studying in?                               object
# CGPA/ percentage                                             float64
# Expected Graduation-year                                       int64
# Areas of interest                                             object
# Current Employment Status                                     object
# Have you worked core Java                                     object
# Programming Language Known other than Java (one major)        object
# Have you worked on MySQL or Oracle database                   object
# Have you studied OOP Concepts                                 object
# Certifications/Achievement/ Research papers                  float64
# Rate your written communication skills [1-10]                  int64
# Rate your verbal communication skills [1-10]                   int64
# Link to updated Resume (Google/ One Drive link preferred)    float64
# link to Linkedin profile                                     float64
# How Did You Hear About This Internship?                       object
# Label                                                         object
# dtype: object

# %%
# Drop the columns of null values
df.drop(['Certifications/Achievement/ Research papers', 'Link to updated Resume (Google/ One Drive link preferred)', 'link to Linkedin profile'],1,inplace=True)

# %%
# Check the data agian for null values
df.isnull().sum()
# Out:
# First Name                                                0
# Last Name                                                 0
# City                                                      0
# State                                                     0
# Zip Code                                                  0
# DOB [DD/MM/YYYY]                                          0
# Age                                                       0
# Gender                                                    0
# Email Address                                             0
# Contact Number                                            0
# Emergency Contact Number                                  0
# College name                                              0
# University Name                                           0
# Degree                                                    0
# Major/Area of Study                                       0
# Course Type                                               0
# Which-year are you studying in?                           0
# CGPA/ percentage                                          0
# Expected Graduation-year                                  0
# Areas of interest                                         0
# Current Employment Status                                 0
# Have you worked core Java                                 0
# Programming Language Known other than Java (one major)    0
# Have you worked on MySQL or Oracle database               0
# Have you studied OOP Concepts                             0
# Rate your written communication skills [1-10]             0
# Rate your verbal communication skills [1-10]              0
# How Did You Hear About This Internship?                   0
# Label                                                     0
# dtype: int64

# %% [markdown]
# #### The number of students applied to different technologies.

# %%
# Strip the data
df["Areas of interest"]=df["Areas of interest"].apply(lambda x: x.strip())

# %%
# Value counts of students applied for different technologies
df["Areas of interest"].value_counts()
# Out:
# DevOps                     674
# Machine Learning           671
# Python                     652
# Cyber Security             638
# Web Development            637
# QMS/Testing                633
# Mobility                   631
# IoT                        630
# Artificial Intelligence    627
# Digital Marketing          624
# Blockchain                 623
# Big Data                   612
# Data Science               601
# Information Security       598
# RPA                        589
# Cloud Computing            560
# Name: Areas of interest, dtype: int64

# %%
# Graph of students applied for different technologies
plt.figure(figsize=(10,5))
df["Areas of interest"].value_counts().plot(kind="bar")
plt.title("Students applied for different technologies")
plt.xlabel("Types of technologies")
plt.ylabel("Number of students")
plt.show()

# %% [markdown]
# #### The number of students applied for Data Science who knew "Python” and who didn’t

# %%
# New dataframe showing students applied for Data Science who knew "Python” and who didn’t
dummy1 = df[df["Areas of interest"] == "Data Science"]["Programming Language Known other than Java (one major)"]

# %%
# Sorting values in yes and no using the apply method
var = dummy1.apply(lambda x: "YES" if x == "Python" else "NO").value_counts()

# %%
# Number of students applied for Data Science who knew "Python” and who didn’t
var
# Out:
# NO     535
# YES     66
# Name: Programming Language Known other than Java (one major), dtype: int64

# %%
# Graph of students applied for Data Science who knew "Python” and who didn’t
var.plot.bar(figsize=(6,5))
plt.text(x = -0.05, y = var[0]+5, s = var[0])
plt.text(x = 0.98, y = var[1]+5, s = var[1])
plt.title("The number of students applied for Data Science who knew Python and who didn’t")
plt.xlabel("Know Python")
plt.ylabel("Number of students")
plt.show()

# %% [markdown]
# #### The different ways students learned about this program

# %%
# Different ways students learned about this program 
print(df["How Did You Hear About This Internship?"].nunique())
# Out:
# 9

# %%
# Counts of different ways students learned about this program
df["How Did You Hear About This Internship?"].value_counts()
# Out:
# Intern                 1173
# Newspaper              1162
# Twitter                1160
# Blog post              1116
# LinkedIn               1112
# Friend                 1109
# Facebook               1084
# Other                  1077
# Ex/Current Employee    1007
# Name: How Did You Hear About This Internship?, dtype: int64

# %%
# Graph of different ways students learned about this program
df["How Did You Hear About This Internship?"].value_counts().plot.bar(figsize=(10,5))
plt.title("Different ways students learned about this program")
plt.xlabel("Types of ways")
plt.ylabel("Number of students")
plt.show()

# %% [markdown]
# #### Students who are in the fourth year and have a CGPA greater than 8.0

# %%
# Number of students who are in the fourth year and have a CGPA greater than 8.0
len(df[(df["Which-year are you studying in?"]=="Fourth-year") & (df["CGPA/ percentage"]>8)])
# Out:
# 1697

# %% [markdown]
# #### Students who applied for Digital Marketing with verbal and written communication score greater than 8

# %%
# Number of students who applied for Digital Marketing with verbal and written communication score greater than 8
len(df[(df["Areas of interest"] == "Digital Marketing") & (df["Rate your written communication skills [1-10]"] > 8) & (df["Rate your verbal communication skills [1-10]"] > 8)])
# Out:
# 92

# %% [markdown]
# #### Year-wise and area of study wise classification of students

# %%
df.groupby(["Which-year are you studying in?","Major/Area of Study"])["Which-year are you studying in?"].count().unstack("Major/Area of Study")
# Out:
# Major/Area of Study              Computer Engineering  Electrical Engineering  \
# Which-year are you studying in?
# First-year                                       1470                     490
# Fourth-year                                      1516                     464
# Second-year                                      1536                     518
# Third-year                                       1449                     561
#
# Major/Area of Study              Electronics and Telecommunication
# Which-year are you studying in?
# First-year                                                     550
# Fourth-year                                                    497
# Second-year                                                    496
# Third-year                                                     453

# %%
# Graph of year-wise and area of study wise classification of students
df.groupby(["Which-year are you studying in?","Major/Area of Study"])["Which-year are you studying in?"].count().unstack("Major/Area of Study").plot(kind='bar', stacked=True)
plt.title("Year-wise and area of study wise classification of students")
plt.ylabel("Number of students")
plt.show()

# %% [markdown]
# #### City and college wise classification of students

# %%
df.groupby(["City", "College name"])["First Name"].count().reset_index(1)
# Out:
#                                                  College name  First Name
# City
# Kolhapur            Bharati Vidyapeeth College of Engineering         834
# Kolhapur       DY Patil College of Engineering And Technology         813
# Mumbai                   K. J. Somaiya College of Engineering         220
# Mumbai                   Rajiv Gandhi Institute of Technology         201
# Mumbai                           Rizvi College of Engineering         222
# Mumbai                    St. Francis Institute of Technology         189
# Mumbai                   Thadomal Shahani Engineering College         192
# Mumbai           Thakur College Of Engineering And Technology         206
# Mumbai                    Vidyalankar Institute of Technology         207
# Mumbai                        Xavier Institute of Engineering         211
# NaviMumbai                 A. C. Patil College of Engineering         309
# NaviMumbai                     Karamveer Bhauro Patil College         378
# NaviMumbai  Mahatma Gandhi Mission's College of Engineerin...         329
# NaviMumbai                      Pillai College of Engineering         356
# NaviMumbai                Ramrao Adik Institute of Technology         306
# Pune                       D. Y. Patil College of Engineering         338
# Pune                Jayawantrao Sawant College of Engineering         327
# Pune                    Pune Institute of Computer Technology         329
# Pune                           Sinhgad College of Engineering         340
# Pune          Vishwakarma Institute of Information Technology         313
# Sangli                    Rajarambapu Institute of Technology        1670
# Solapur     Bharat Ratna Indira Gandhi College of Engineering         417
# Solapur             Brahmdevdada Mane Institute of Technology         428
# Solapur                    Skn Sinhgad College of Engineering         431
# Solapur                      Walchand Institute of Technology         434

# %% [markdown]
# #### Plot the relationship between the CGPA and the target variable

# %%
# New dataframe consisting CGPA and the target variable columns
df_new = df[['CGPA/ percentage',"Label"]]

# %%
bins = [7,7.5,8,8.5,9,9.5,10]
labels = ['7.0 - 7.5', '7.5 - 8.0','8.0 - 8.5', '8.5 - 9.0','9.0 to 9.5','9.5 - 10']

# %%
df_new["Class-Interval"] = pd.cut(df_new["CGPA/ percentage"],bins=bins,labels=labels)
# Out:
# /Users/muustafaqureshii/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_new.groupby(["Class-Interval","Label"])["Class-Interval"].count().unstack("Label")
# Out:
# Label           eligible  ineligible
# Class-Interval
# 7.0 - 7.5             15        1607
# 7.5 - 8.0            816         867
# 8.0 - 8.5            808         874
# 8.5 - 9.0            830         863
# 9.0 to 9.5           840         865
# 9.5 - 10             754         840

# %%
# Graph of relationship between the CGPA and the target variable
df_new.groupby(["Class-Interval","Label"])["Class-Interval"].count().unstack("Label").plot.bar(figsize=(10,6))
plt.title('CGPA vs Target')
plt.xlabel("Class-Interval")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# #### Plot the relationship between the Area of Interest and the target variable

# %%
# New dataframe consisting area of Interest and the target variable columns
df_new1 = df.groupby(['Areas of interest',"Label"])['Areas of interest'].count().unstack("Label")

# %%
# Graph of students interested in different areas
df_new1.plot.bar(figsize=(18,7))
plt.title("Students interested in different areas")
plt.ylabel("Number of students")
plt.show()

# %%
# New columns of Percentage_eligible and Percentage_ineligible
df_new1["Percentage_eligible"] = df_new1["eligible"]*100/(df_new1["eligible"]+df_new1["ineligible"])
df_new1["Percentage_ineligible"] =100- df_new1["Percentage_eligible"]

# %%
df_new1
# Out:
# Label                    eligible  ineligible  Percentage_eligible  \
# Areas of interest
# Artificial Intelligence       253         374            40.350877
# Big Data                      250         362            40.849673
# Blockchain                    271         352            43.499197
# Cloud Computing               214         346            38.214286
# Cyber Security                273         365            42.789969
# Data Science                  246         355            40.931780
# DevOps                        290         384            43.026706
# Digital Marketing             266         358            42.628205
# Information Security          241         357            40.301003
# IoT                           218         412            34.603175
# Machine Learning              266         405            39.642325
# Mobility                      267         364            42.313788
# Python                        269         383            41.257669
# QMS/Testing                   252         381            39.810427
# RPA                           219         370            37.181664
# Web Development               268         369            42.072214
#
# Label                    Percentage_ineligible
# Areas of interest
# Artificial Intelligence              59.649123
# Big Data                             59.150327
# Blockchain                           56.500803
# Cloud Computing                      61.785714
# Cyber Security                       57.210031
# Data Science                         59.068220
# DevOps                               56.973294
# Digital Marketing                    57.371795
# Information Security                 59.698997
# IoT                                  65.396825
# Machine Learning                     60.357675
# Mobility                             57.686212
# Python                               58.742331
# QMS/Testing                          60.189573
# RPA                                  62.818336
# Web Development                      57.927786

# %%
# Graph of relationship between the Area of Interest and the target variable
plt.figure(figsize=(14,6))
plt.title("Area of Interest vs Target")
plt.xlabel("Area Of Interest")
plt.ylabel("Percentage of Students Eligible")
plt.plot(df_new1["Percentage_eligible"],marker="D")
plt.xticks(ticks=range(1,17),labels=list(df_new1.index),rotation="vertical")
plt.show()

# %% [markdown]
# #### Plot the relationship between the year of study, major, and the target variable

# %%
# New dataframe consisting Major/Area of Study, Which-year are you studying in? and the target variable
df_new2=df.groupby(['Major/Area of Study','Which-year are you studying in?','Label'])['Major/Area of Study'].count().unstack(['Label'])

# %%
# New column of Percentage_eligible
df_new2["Percent_Eligible"] = df_new2["eligible"]*100/(df_new2["eligible"]+df_new2["ineligible"])

# %%
df_new2=df_new2.fillna(0)

# %%
df_new2
# Out:
# Label                                                              eligible  \
# Major/Area of Study               Which-year are you studying in?
# Computer Engineering              First-year                            0.0
#                                   Fourth-year                         815.0
#                                   Second-year                         818.0
#                                   Third-year                          801.0
# Electrical Engineering            First-year                            0.0
#                                   Fourth-year                         259.0
#                                   Second-year                         274.0
#                                   Third-year                          302.0
# Electronics and Telecommunication First-year                            0.0
#                                   Fourth-year                         275.0
#                                   Second-year                         273.0
#                                   Third-year                          246.0
#
# Label                                                              ineligible  \
# Major/Area of Study               Which-year are you studying in?
# Computer Engineering              First-year                           1470.0
#                                   Fourth-year                           701.0
#                                   Second-year                           718.0
#                                   Third-year                            648.0
# Electrical Engineering            First-year                            490.0
#                                   Fourth-year                           205.0
#                                   Second-year                           244.0
#                                   Third-year                            259.0
# Electronics and Telecommunication First-year                            550.0
#                                   Fourth-year                           222.0
#                                   Second-year                           223.0
#                                   Third-year                            207.0
#
# Label                                                              Percent_Eligible
# Major/Area of Study               Which-year are you studying in?
# Computer Engineering              First-year                               0.000000
#                                   Fourth-year                             53.759894
#                                   Second-year                             53.255208
#                                   Third-year                              55.279503
# Electrical Engineering            First-year                               0.000000
#                                   Fourth-year                             55.818966
#                                   Second-year                             52.895753
#                                   Third-year                              53.832442
# Electronics and Telecommunication First-year                               0.000000
#                                   Fourth-year                             55.331992
#                                   Second-year                             55.040323
#                                   Third-year                              54.304636

# %%
df_new2[["eligible" ,"ineligible"]].plot.bar(figsize=(14,6))
plt.title("Relationship between the year of study, major, and the target variable")
plt.ylabel("Number of students")
plt.show()

# %% [markdown]
# #### Identify the best binary classifier to classify data into “eligible/1” and “not eligible/0”

# %%
X=df[['Age', 'Gender','Major/Area of Study', 'Which-year are you studying in?',
       'CGPA/ percentage', 'Areas of interest','Have you worked core Java',
       'Programming Language Known other than Java (one major)',
       'Have you worked on MySQL or Oracle database',
       'Have you studied OOP Concepts',
       'Rate your written communication skills [1-10]',
       'Rate your verbal communication skills [1-10]']]

# %%
y=df["Label"]

# %%
X.shape,y.shape
# Out:
# ((10000, 12), (10000,))

# %%
X=pd.get_dummies(X,drop_first=True)

# %%
x_col=X.columns

# %%
X.corr().style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# <style  type="text/css" >
#     #T_f6bb60ba_b6df_11ea_ab1f_38c986192219row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_f6bb60ba_b6df_11ea_ab1f_38c986192219row0_col1 {
#             background-color:  #4055c8;
#             color:  #f1f1f1;
#         }    #T_f6bb60ba_b6df_11ea_ab1f_38c986192219row0_col2 {
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }    #T_f6bb60ba_b6df_11ea_ab1f_38c986192219row0_col3 {
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }    #T_f6bb60ba_b6df_11ea_ab1f_38c986192219row0_col4 {
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }    #T_f6bb60ba_b6df_11ea_ab1f_38c986192219row0_col5 {
#             background-color:  #7da0f9;
#             color:  #000000;
#         }    #T_f6bb60ba_b6df_11ea_ab1f_38c986192219row0_col6 {
#             background-color:  #7b9ff9;
#             color:  #000000;
#         }    #T_f6bb60ba_b6df_11ea_ab1f_38c986192219row0_col7 {
#             background-color:  #90b2fe;
#             color:  #000000;
#         }    #T_f6bb60ba_b6df_11ea_ab1f_38c986192219row0_col8 {
#             background-color:  #8badfd;
#             color:  #000000;
#         }    #T_f6bb60ba_b6df_11ea_ab1f_38c986192219row0_col9 {
#             background-color:  #8db0fe;
#             color:  #000000;
#         }    #T_f6bb60ba_b6df_11ea_ab1f_38c986192219row0_col10 {
#             background-color:  #4e68d8;
#             color:  #000000;
#         }    #T_f6bb60ba_b6df_11ea_ab1f_38c986192219row0_col11 {
#             background-color:  #516ddb;
#             color:  #000000;
#         }    #T_f6bb60ba_b6df_11ea_ab1f_38c986192219row0_col12 {
#             background-color:  #516ddb;
#             color:  #000000;
#         }    #T_f6bb60ba_b6df_11ea_ab1f_38c986192219row0_col13 {
#             background-color:  #4f69d9;
#             color:  #000000;
#         }    #T_f6bb60ba_b6df_11ea_ab1f_38c986192219row0_col14 {
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }    #T_f6bb60ba_b6df_11ea_ab1f_38c986192219row0_col15 {
#             background-color:  #4b64d5;
#             color:  #f1f1f1;
#         }    #T_f6bb60ba_b6df_11ea_ab1f_38c986192219row0_col16 {
#             background-color:  #4f69d9;
#             color:  #000000;
#         }    #T_f6bb60ba_b6df_11ea_ab1f_38c986192219row0_col17 {
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }    #T_f6bb60ba_b6df_11ea_ab1f_38c986192219row0_col18 {
#             background-color:  #516ddb;
#             color:  #000000;
#         }    #T_f6bb60ba_b6df_11ea_ab1f_38c986192219row0_col19 {
#             background-color:  #516ddb;
#             color:  #000000;
#         }    #T_f6bb60ba_b6df_11ea_ab1f_38c986192219row0_col20 {
#             background-color:  #4b64d5;
#             color:  #f1f1f1;
#         }    #T_f6bb60ba_b6df_11ea_ab1f_38c986192219row0_col21 {
#             background-color:  #4e68d8;
#             color:  #000000;
#         }    #T_f6bb60ba_b6df_11ea_ab1f_38c986192219row0_col22 {
#             background-color:  #4e68d8;
#             color:  #000000;
#         }    #T_f6bb60ba_b6df_11ea_ab1f_38c986192219row0_col23 {
#             background-color:  #506bda;
#             color:  #000000;
#         }    #T_f6bb60ba_b6df_11ea_ab1f_38c986192219row0_col24 {
#             background-color:  #485fd1;
#             color:  #f1f1f1;
#         }    #T_f6bb60ba_b6df_11ea_ab1f_38c986192219row0_col25 {
#             background-color:  #465ecf;
#             color:  #f1f1f1;
#         }    #T_f6bb60ba_b6df_11ea_ab1f_38c986192219row0_col26 {
#             background-color:  #5e7de7;
#             color:  #000000;
#         }    #T_f6bb60ba_b6df_11ea_ab1f_38c986192219row0_col27 {
#             background-color:  #6687ed;
#             color:  #000000;
#         }    #T_f6bb60ba_b6df_11ea_ab1f_38c986192219row0_col28 {
#             background-color:  #6384eb;
#             color:  #000000;
#         }    #T_f6bb60ba_b6df_11ea_ab1f_38c986192219row0_col29 {
#             background-color:  #6384eb;
#             color:  #000000;
#         }    #T_f6bb60ba_b6df_11ea_ab1f_38c986192219row0_col30 {
#             background-color:  #6687ed;
#             color:  #000000;
#         }    #T_f6bb60ba_b6df_11ea_ab1f_38c986192219row0_col31 {
#             background-color:  #5f7fe8;
#             color:  #000000;
#         }    #T_f6bb60ba_b6df_11ea_ab1f_38c986192219row0_col32 {
#             background-color:  #6384eb;
#             color:  #000000;
#         }    #T_f6bb60ba_b6df_11ea_ab1f_38c986192219row0_col33 {
#             background-color:  #455cce;
#             color:  #f1f1f1;
#         }    #T_f6bb60ba_b6df_11ea_ab1f_38c986192219row0_col34 {
#             background-color:  #4055c8;
#             color:  #f1f1f1;
#         }    #T_f6bb60ba_b6df_11ea_ab1f_38c986192219row1_col0 {
#             background-color:  #445acc;
#             color:  #f1f1f1;
#         }    #T_f6bb60ba_b6df_11ea_ab1f_38c986192219row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_f6bb60ba_b6df_11ea_ab1f_38c986192219row1_col2 {
#             background-color:  #4257c9;
#             color:  #f1f1f1;
#         }    #T_f6bb60ba_b6df_11ea_ab1f_38c986192219row1_col3 {
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }    #T_f6bb60ba_b6df_11ea_ab1f_38c986192219row1_col4 {
#             background-color:  #4055c8;
#             color:  #f1f1f1;
#         }    #T_f6bb60ba_b6df_11ea_ab1f_38c986192219row1_col5 {
#             background-color:  #7b9ff9;
#             color:  #000000;
#         }    #T_f6bb60ba_b6df_11ea_ab1f_38c986192219row1_col6 {
#             background-color:  #7ea1fa;
#             color:  #000000;
#         }    #T_f6bb60ba_b6df_11ea_ab1f_38c986192219row1_col7 {
#             background-color:  #94b6ff;
#             color:  #000000;
#         }    #T_f6bb60ba_b6df_11ea_ab1f_38c986192219row1_col8 {
#             background-color:  #8db0fe;
#             color:  #000000;
#         }    #T_f6bb60ba_b6df_11ea_ab1f_38c986192219row1_col9 {
#             background-color:  #89acfd;
#             color:  #000000;
#         }    #T_f6bb60ba_b6df_11ea_ab1f_38c986192219row1_col10 {
#             background-color:  #4b64d5;
#             color:  #f1f1f1;
#         }    #T_f6bb60ba_b6df_11ea_ab1f_38c986192219row1_col11 {
#             background-color:  #506bda;
#             color:  #000000;
#         }    #T_f6bb60ba_b6df_11ea_ab1f_38c986192219row1_col12 {
#             background-color:  #4c66d6;
#             color:  #000000;
#         }    #T_f6bb60ba_b6df_11ea_ab1f_38c986192219row1_col13 {
#             background-color:  #5572df;
#             color:  #000000;
#         }    #T_f6bb60ba_b6df_11ea_ab1f_38c986192219row1_col14 {
#             background-color:  #4f69d9;
#             color:  #000000;
#         }    #T_f6bb60ba_b6df_11ea_ab1f_38c986192219row1_col15 {
#             background-color:  #4e68d8;
#             color:  #000000;
#         }    #T_f6bb60ba_b6df_11ea_ab1f_38c986192219row1_col16 {
#             background-color:  #506bda;
#             color:  #000000;
#         }    #T_f6bb60ba_b6df_11ea_ab1f_38c986192219row1_col17 {
#             background-color:  #4b64d5;
#             color:  #f1f1f1;
#         }    #T_f6bb60ba_b6df_11ea_ab1f_38c986192219row1_col18 {
#             background-color:  #4b64d5;
#             color:  #f1f1f1;
#         }    #T_f6bb60ba_b6df_11ea_ab1f_38c986192219row1_col19 {
#             background-color:  #4e68d8;
#             color:  #000000;
#         }    #T_f6bb60ba_b6df_11ea_ab1f_38c986192219row1_col20 {
#             background-color:  #516ddb;
#             color:  #000000;
#         }    #T_f6bb60ba_b6df_11ea_ab1f_38c986192219row1_col21 {
#             background-color:  #4f69d9;
#             color:  #000000;
#         }    #T_f6bb60ba_b6df_11ea_ab1f_38c986192219row1_col22 {
#             background-color:  #4c66d6;
#             color:  #000000;
#         }    #T_f6bb60ba_b6df_11ea_ab1f_38c986192219row1_col23 {
#             background-color:  #4b64d5;
#             color:  #f1f1f1;
#         }    #T_f6bb60ba_b6df_11ea_ab1f_38c986192219row1_col24 {
#             background-color:  #

# %%
# import StandardScaler
from sklearn.preprocessing import StandardScaler

sc=StandardScaler()

# %%
X = sc.fit_transform(X)

# %%
# Encode the data into “eligible/1” and “not eligible/0”
y = y.apply(lambda x: 1 if x == 'eligible' else 0)

# %%
X = pd.DataFrame(X,columns = x_col)

# %%
# import train_test_split
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2, random_state=142)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((8000, 35), (2000, 35), (8000,), (2000,))

# %%
# import the classifiers
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier

# %%
y.value_counts()
# Out:
# 0    5937
# 1    4063
# Name: Label, dtype: int64

# %%
dt = DecisionTreeClassifier(random_state = 142)
rf = RandomForestClassifier(random_state = 142)
lr = LogisticRegression(random_state = 142)
kn = KNeighborsClassifier(n_neighbors = 1)

# %%
# fit the data
dt.fit(X_train,y_train)
rf.fit(X_train,y_train)
lr.fit(X_train,y_train)
kn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=1, p=2,
#                      weights='uniform')

# %%
dt_pred = dt.predict(X_test)
rf_pred = rf.predict(X_test)
lr_pred = lr.predict(X_test)
kn_pred = kn.predict(X_test)

# %%
# import accuracy_score, f1_score, confusion_matrix
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix

# %% [markdown]
# ##### Decision Tree

# %%
# print accuracy
print("Accuracy is:", accuracy_score(y_test, dt_pred))
# Out:
# Accuracy is: 1.0

# %%
# print f1 score
print("f1 score is:", f1_score(y_test, dt_pred))
# Out:
# f1 score is: 1.0

# %%
# print confusion matrix
from mlxtend.plotting import plot_confusion_matrix

fig, ax = plot_confusion_matrix(conf_mat=confusion_matrix(y_test, dt_pred),figsize=(6,6))
plt.title("Confusion Matrix for Decision Tree")
plt.show()

# %% [markdown]
# ##### Random Forest

# %%
# print accuracy
print("Accuracy is:", accuracy_score(y_test, rf_pred))
# Out:
# Accuracy is: 1.0

# %%
# print f1 score
print("f1 score is:", f1_score(y_test, rf_pred))
# Out:
# f1 score is: 1.0

# %%
# print confusion matrix
fig, ax = plot_confusion_matrix(conf_mat=confusion_matrix(y_test, rf_pred),figsize=(6,6))
plt.title("Confusion Matrix for Random Forest")
plt.show()

# %% [markdown]
# ##### Logistic Regression

# %%
# print accuracy
print("Accuracy is:", accuracy_score(y_test, lr_pred))
# Out:
# Accuracy is: 0.8345

# %%
# print f1 score
print("f1 score is:", f1_score(y_test, lr_pred))
# Out:
# f1 score is: 0.7973055725658299

# %%
# print confusion matrix
fig, ax = plot_confusion_matrix(conf_mat=confusion_matrix(y_test, lr_pred),figsize=(6,6))
plt.title("Confusion Matrix for Logistic Regression")
plt.show()

# %% [markdown]
# ##### KNN

# %%
# print accuracy
print("Accuracy is:", accuracy_score(y_test, kn_pred))
# Out:
# Accuracy is: 0.6605

# %%
# print f1 score
print("f1 score is:", f1_score(y_test, kn_pred))
# Out:
# f1 score is: 0.5946268656716418

# %%
# print confusion matrix
fig, ax = plot_confusion_matrix(conf_mat=confusion_matrix(y_test, kn_pred),figsize=(6,6))
plt.title("Confusion Matrix for KNN")
plt.show()

# %% [markdown]
# ###### The best model is Decision Tree and Random Forest  which gives the accuracy of 100%. But I will be going with Decision tree as Decision tree is simple model and uses less resources than Random Forest

# %% [markdown]
# ##### Using the feature importance for finding out the most important columns, to get the best model

# %% [markdown]
# ##### Feature Importance

# %%
for i, j in zip(x_col,rf.feature_importances_):
    print(i,round(j*100,2))
# Out:
# Age 2.06
# CGPA/ percentage 18.18
# Rate your written communication skills [1-10] 20.29
# Rate your verbal communication skills [1-10] 21.48
# Gender_Male 0.72
# Major/Area of Study_Electrical Engineering 0.56
# Major/Area of Study_Electronics and Telecommunication 0.6
# Which-year are you studying in?_Fourth-year 8.4
# Which-year are you studying in?_Second-year 9.31
# Which-year are you studying in?_Third-year 9.42
# Areas of interest_Big Data 0.24
# Areas of interest_Blockchain 0.28
# Areas of interest_Cloud Computing 0.25
# Areas of interest_Cyber Security 0.26
# Areas of interest_Data Science 0.25
# Areas of interest_DevOps 0.25
# Areas of interest_Digital Marketing 0.26
# Areas of interest_Information Security 0.26
# Areas of interest_IoT 0.28
# Areas of interest_Machine Learning 0.27
# Areas of interest_Mobility 0.27
# Areas of interest_Python 0.26
# Areas of interest_QMS/Testing 0.26
# Areas of interest_RPA 0.29
# Areas of interest_Web Development 0.27
# Have you worked core Java_Yes 0.64
# Programming Language Known other than Java (one major)_C 0.38
# Programming Language Known other than Java (one major)_C# 0.42
# Programming Language Known other than Java (one major)_C++ 0.39
# Programming Language Known other than Java (one major)_HTML/CSS 0.37
# Programming Language Known other than Java (one major)_JavaScript 0.44
# Programming Language Known other than Java (one major)_PHP 0.39
# Programming Language Known other than Java (one major)_Python 0.37
# Have you worked on MySQL or Oracle database_Yes 0.79
# Have you studied OOP Concepts_Yes 0.81

# %%
X_train
# Out:
#            Age  CGPA/ percentage  \
# 4665 -0.929579         -1.500096
# 7168  0.413064          0.999560
# 7132  0.413064          1.057692
# 939   0.413064         -1.604732
# 4908 -1.600900         -1.627985
# ...        ...               ...
# 6317 -1.600900          1.208834
# 5146 -0.929579         -0.674628
# 7436 -0.929579          0.081082
# 7365  1.084386          1.348349
# 277  -0.929579         -0.872275
#
#       Rate your written communication skills [1-10]  \
# 4665                                       0.715691
# 7168                                       0.008207
# 7132                                       0.715691
# 939                                        0.715691
# 4908                                       0.715691
# ...                                             ...
# 6317                                      -0.699278
# 5146                                       0.008207
# 7436                                       0.008207
# 7365                                      -1.406762
# 277                                        0.008207
#
#       Rate your verbal communication skills [1-10]  Gender_Male  \
# 4665                                      0.003171    -0.996406
# 7168                                      0.003171     1.003607
# 7132                                      0.003171    -0.996406
# 939                                       0.003171     1.003607
# 4908                                      0.003171     1.003607
# ...                                            ...          ...
# 6317                                     -0.701530    -0.996406
# 5146                                      0.003171    -0.996406
# 7436                                      0.003171    -0.996406
# 7365                                     -0.701530    -0.996406
# 277                                       0.003171    -0.996406
#
#       Major/Area of Study_Electrical Engineering  \
# 4665                                   -0.505151
# 7168                                   -0.505151
# 7132                                   -0.505151
# 939                                    -0.505151
# 4908                                   -0.505151
# ...                                          ...
# 6317                                   -0.505151
# 5146                                   -0.505151
# 7436                                    1.979606
# 7365                                   -0.505151
# 277                                    -0.505151
#
#       Major/Area of Study_Electronics and Telecommunication  \
# 4665                                          -0.499375
# 7168                                          -0.499375
# 7132                                          -0.499375
# 939                                            2.002503
# 4908                                          -0.499375
# ...                                                 ...
# 6317                                          -0.499375
# 5146                                          -0.499375
# 7436                                          -0.499375
# 7365                                          -0.499375
# 277                                            2.002503
#
#       Which-year are you studying in?_Fourth-year  \
# 4665                                    -0.573809
# 7168                                    -0.573809
# 7132                                    -0.573809
# 939                                     -0.573809
# 4908                                    -0.573809
# ...                                           ...
# 6317                                    -0.573809
# 5146                                    -0.573809
# 7436                                    -0.573809
# 7365                                    -0.573809
# 277                                     -0.573809
#
#       Which-year are you studying in?_Second-year  \
# 4665                                     1.709260
# 7168                                     1.709260
# 7132                                    -0.585049
# 939                                      1.709260
# 4908                                    -0.585049
# ...                                           ...
# 6317                                     1.709260
# 5146                                    -0.585049
# 7436                                     1.709260
# 7365                                     1.709260
# 277                                     -0.585049
#
#       Which-year are you studying in?_Third-year  Areas of interest_Big Data  \
# 4665                                   -0.571654                   -0.255323
# 7168                                   -0.571654                   -0.255323
# 7132                                   -0.571654                   -0.255323
# 939                                    -0.571654                   -0.255323
# 4908                                    1.749311                   -0.255323
# ...                                          ...                         ...
# 6317                                   -0.571654                   -0.255323
# 5146                                   -0.571654                   -0.255323
# 7436                                   -0.571654                   -0.255323
# 7365                                   -0.571654                   -0.255323
# 277                                    -0.571654                   -0.255323
#
#       Areas of interest_Blockchain  Areas of interest_Cloud Computing  \
# 4665                     -0.257758                          -0.243561
# 7168                     -0.257758                          -0.243561
# 7132                     -0.257758                          -0.243561
# 939                      -0.257758                          -0.243561
# 4908                     -0.257758                          -0.243561
# ...                            ...                                ...
# 6317                     -0.257758                           4.105745
# 5146                     -0.257758                          -0.243561
# 7436                     -0.257758                          -0.243561
# 7365                     -0.257758                          -0.243561
# 277                      -0.257758                          -0.243561
#
#       Areas of interest_Cyber Security  Areas of interest_Data Science  \
# 4665                         -0.261051                       -0.252869
# 7168                          3.830663                       -0.252869
# 7132                         -0.261051                       -0.252869
# 939                          -0.261051                       -0.252869
# 4908                         -0.261051                       -0.252869
# ...                                ...                             ...
# 6317                         -0.261051                       -0.252869
# 5146                         -0.261051                       -0.252869
# 7436                         -0.261051                       -0.252869
# 7365                         -0.261051                       -0.252869
# 277                          -0.261051                       -0.252869
#
#       Areas of interest_DevOps  Areas of interest_Digital Marketing  \
# 4665                 -0.268833                            -0.257978
# 7168                 -0.268833                            -0.257978
# 7132                 -0.268833                            -0.257978
# 939                  -0.268833                            -0.257978
# 4908                  3.719784                            -0.257978
# ...                        ...                                  ...
# 6317                 -0.268833                            -0.257978
# 5146                 -0.268833                            -0.257978
# 7436                 -0.268833                            -0.257978
# 7365                 -0.268833                            -0.257978
# 277                  -0.268833                            -0.257978
#
#       Areas of interest_Information Security  Areas of interest_IoT  \
# 4665                               -0.252197              -0.259299
# 7168                               -0.252197              -0.259299
# 7132                               -0.252197               3.856555
# 939                                -0.252197              -0.259299
# 4908                               -0.252197              -0.259299
# ...                                      ...                    ...
# 6317                               -0.252197              -0.259299
# 5146                               -0.252197              -0.259299
# 7436                               -0.252197              -0.259299
# 7365                               -0.252197              -0.259299
# 277                                -0.252197               3.856555
#
#       Areas of interest_Machine Learning  Areas of interest_Mobility  \
# 4665                           -0.268191                   -0.259518
# 7168                           -0.268191                   -0.259518
# 7132                           -0.268191                   -0.259518
# 939                            -0.268191                   -0.259518
# 4908                           -0.268191                   -0.259518
# ...                                  ...                         ...
# 6317                           -0.268191                   -0.259518
# 5146                            3.728690                   -0.259518
# 7436                           -0.268191                   -0.259518
# 7365                           -0.268191                   -0.259518
# 277                            -0.268191                   -0.259518
#
#       Areas of interest_Python  Areas of interest_QMS/Testing  \
# 4665                 -0.264098                       3.846789
# 7168                 -0.264098                      -0.259957
# 7132                 -0.264098                      -0.259957
# 939                  -0.264098                      -0.259957
# 4908                 -0.264098                      -0.259957
# ...                        ...                            ...
# 6317                 -0.264098                      -0.259957
# 5146                 -0.264098                      -0.259957
# 7436                 -0.264098                      -0.259957
# 7365                  3.786479                      -0.259957
# 277                  -0.264098                      -0.259957
#
#       Areas of interest_RPA  Areas of interest_Web Development  \
# 4665              -0.250173                          -0.260833
# 7168              -0.250173                          -0.260833
# 7132              -0.250173                          -0.260833
# 939                3.997240                          -0.260833
# 4908              -0.250173                          -0.260833
# ...                     ...                                ...
# 6317              -0.250173                          -0.260833
# 5146              -0.250173                          -0.260833
# 7436              -0.250173                           3.833874
# 7365              -0.250173                          -0.260833
# 277               -0.250173                          -0.260833
#
#       Have you worked core Java_Yes  \
# 4665                      -0.993819
# 7168                      -0.993819
# 7132                       1.006219
# 939                       -0.993819
# 4908                       1.006219
# ...                             ...
# 6317                       1.006219
# 5146                      -0.993819
# 7436                       1.006219
# 7365                       1.006219
# 277                       -0.993819
#
#       Programming Language Known other than Java (one major)_C  \
# 4665                                          -0.381068
# 7168                                          -0.381068
# 7132                                          -0.381068
# 939                                           -0.381068
# 4908                                           2.624202
# ...                                                 ...
# 6317                                          -0.381068
# 5146                                          -0.381068
# 7436                                          -0.381068
# 7365                                          -0.381068
# 277                                            2.624202
#
#       Programming Language Known other than Java (one major)_C#  \
# 4665                                          -0.380207
# 7168                                          -0.380207
# 7132                                          -0.380207
# 939                                           -0.380207
# 4908                                          -0.380207
# ...                                                 ...
# 6317                                          -0.380207
# 5146                                          -0.380207
# 7436                                           2.630144
# 7365                                          -0.380207
# 277                                           -0.380207
#
#       Programming Language Known other than Java (one major)_C++  \
# 4665                                          -0.377792
# 7168                                          -0.377792
# 7132                                           2.646961
# 939                                           -0.377792
# 4908                                          -0.377792
# ...                                                 ...
# 6317                                           2.646961
# 5146                                          -0.377792
# 7436                                          -0.377792
# 7365                                          -0.377792
# 277                                           -0.377792
#
#       Programming Language Known other than Java (one major)_HTML/CSS  \
# 4665                                          -0.373285
# 7168                                          -0.373285
# 7132                                          -0.373285
# 939                                           -0.373285
# 4908                                          -0.373285
# ...                                                 ...
# 6317                                          -0.373285
# 5146                                           2.678920
# 7436                                          -0.373285
# 7365                                          -0.373285
# 277                                           -0.373285
#
#       Programming Language Known other than Java (one major)_JavaScript  \
# 4665                                          -0.385872
# 7168                                          -0.385872
# 7132                                          -0.385872
# 939                                           -0.385872
# 4908                                          -0.385872
# ...                                                 ...
# 6317                                          -0.385872
# 5146                                          -0.385872
# 7436                                          -0.385872
# 7365                                           2.591534
# 277                                           -0.385872
#
#       Programming Language Known other than Java (one major)_PHP  \
# 4665                                           2.704173
# 7168                                           2.704173
# 7132                                          -0.369799
# 939                                            2.704173
# 4908                                          -0.369799
# ...                                                 ...
# 6317                                          -0.369799
# 5146                                          -0.369799
# 7436                                          -0.369799
# 7365                                          -0.369799
# 277                                           -0.369799
#
#       Programming Language Known other than Java (one major)_Python  \
# 4665                                          -0.373459
# 7168                                          -0.373459
# 7132                                          -0.373459
# 939                                           -0.373459
# 4908                                          -0.373459
# ...                                                 ...
# 6317                                          -0.373459
# 5146                                          -0.373459
# 7436                                          -0.373459
# 7365                                          -0.373459
# 277                                           -0.373459
#
#       Have you worked on MySQL or Oracle database_Yes  \
# 4665                                         0.998601
# 7168                                        -1.001401
# 7132                                        -1.001401
# 939                                         -1.001401
# 4908                                        -1.001401
# ...                                               ...
# 6317                                         0.998601
# 5146                                        -1.001401
# 7436                                         0.998601
# 7365                                        -1.001401
# 277                                         -1.001401
#
#       Have you studied OOP Concepts_Yes
# 4665                          -1.008839
# 7168                           0.991238
# 7132                           0.991238
# 939                            0.991238
# 4908                          -1.008839
# ...                                 ...
# 6317                          -1.008839
# 5146                          -1.008839
# 7436                          -1.008839
# 7365                          -1.008839
# 277                           -1.008839
#
# [8000 rows x 35 columns]

# %%
# splitting data into X_train
X_train = X_train[["CGPA/ percentage", "Rate your written communication skills [1-10]", "Rate your verbal communication skills [1-10]"]]

# %%
# splitting data into X_test
X_test = X_test[["CGPA/ percentage", "Rate your written communication skills [1-10]", "Rate your verbal communication skills [1-10]"]]

# %%
# fit the data
dt.fit(X_train,y_train)
rf.fit(X_train,y_train)
lr.fit(X_train,y_train)
kn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=1, p=2,
#                      weights='uniform')

# %%
dt_pred = rf.predict(X_test)
rf_pred = rf.predict(X_test)
lr_pred = lr.predict(X_test)
kn_pred = kn.predict(X_test)

# %% [markdown]
# ##### Decision Tree

# %%
# print accuracy
print("Accuracy is:", accuracy_score(y_test, dt_pred))
# Out:
# Accuracy is: 0.8095

# %%
# print f1 score
print("f1 score is:", f1_score(y_test, dt_pred))
# Out:
# f1 score is: 0.7666870789957135

# %%
# print confusion matrix
fig, ax = plot_confusion_matrix(conf_mat=confusion_matrix(y_test, dt_pred),figsize=(6,6))
plt.title("Confusion Matrix for Decision Tree")
plt.show()

# %% [markdown]
# ##### Random Forest

# %%
# print accuracy
print("Accuracy is:", accuracy_score(y_test, rf_pred))
# Out:
# Accuracy is: 0.8095

# %%
# print f1 score
print("f1 score is:", f1_score(y_test, rf_pred))
# Out:
# f1 score is: 0.7666870789957135

# %%
# print confusion matrix
fig, ax = plot_confusion_matrix(conf_mat=confusion_matrix(y_test, rf_pred),figsize=(6,6))
plt.title("Confusion Matrix for Random Forest")
plt.show()

# %% [markdown]
# ##### Logistic Regression

# %%
# print accuracy
print("Accuracy is:", accuracy_score(y_test, lr_pred))
# Out:
# Accuracy is: 0.7125

# %%
# print f1 score
print("f1 score is:", f1_score(y_test, lr_pred))
# Out:
# f1 score is: 0.6174318030605456

# %%
# print confusion matrix
fig, ax = plot_confusion_matrix(conf_mat=confusion_matrix(y_test, lr_pred),figsize=(6,6))
plt.title("Confusion Matrix for Logistic Regression")
plt.show()

# %% [markdown]
# ##### KNN

# %%
# print accuracy
print("Accuracy is:", accuracy_score(y_test, kn_pred))
# Out:
# Accuracy is: 0.8

# %%
# print f1 score
print("f1 score is:", f1_score(y_test, kn_pred))
# Out:
# f1 score is: 0.75

# %%
# print confusion matrix
fig, ax = plot_confusion_matrix(conf_mat=confusion_matrix(y_test, kn_pred),figsize=(6,6))
plt.title("Confusion Matrix for KNN")
plt.show()

# %% [markdown]
# ##### After using the only  feature important features,  Decision Tree and Random Forest are able to predict with 80.95% accuracy
